# %%
import matplotlib;
import matplotlib.pyplot as plt;

#X, Y = [120,1400,20000,40000], [100,1000,10000,100000];
X = [];
Y1 = [];
Y2 = [];
Y3 = [];

for line in open('qsVmsVhs.dat', 'r'):
    values = [float(s) for s in line.split()];

    if(values):
        #print(Y1);
        #print(Y2);
        #print(Y3);
        #print(X);
        Y1.append(values[0]);
        Y2.append(values[1]);
        Y3.append(values[2]);
        X.append(values[3]);
    
#print(X)
plt.figure(figsize=(20,20));
plt.xlabel('No of items');
plt.ylabel('Time(ms)');
plt.plot(X,Y1,label="Quicksort");
plt.plot(X,Y2,label="Mergesort");
plt.plot(X,Y3,label="Heapsort");

plt.legend(bbox_to_anchor=(0., 1.02, 1., 2.102), loc=3, ncol=2, mode="expand", borderaxespad=0.);
#plt.show();
plt.savefig('qsVmsVhs.png');
# Out:
# []
# []
# []
# []
# [1.1e-05]
# [2.4e-05]
# [1.9e-05]
# [100.0]
# [1.1e-05, 0.000177]
# [2.4e-05, 0.000259]
# [1.9e-05, 0.000252]
# [100.0, 1000.0]
# [1.1e-05, 0.000177, 0.003714]
# [2.4e-05, 0.000259, 0.002603]
# [1.9e-05, 0.000252, 0.003132]
# [100.0, 1000.0, 10000.0]
